# %% [markdown]
# # Self Experimentation in Personal Health Informatics

# %% [markdown]
# ## Introduction
# In this assignment, we will harness personal data from platforms such as Apple Health, Google Fit, and Fitbit to conduct self-experimentation. You'll learn the technical processes of data extraction, including the use of APIs and data export functions provided by these platforms. Following extraction, we will delve into data cleaning techniques to ensure data quality and usability, addressing common issues such as outliers, missing values, and data format inconsistencies.
#
# You will then apply statistical methods and data visualization tools to analyze and interpret your health and activity metrics. This analysis will help you identify trends and correlations within your personal data. Additionally, we will integrate reflective prompts to foster critical thinking about the implications of data findings on your personal health decisions.

# %% [markdown]
# ## Export Your Data
#
# In this assignment, we will guide you through the process of exporting data from three major platforms: Apple (iPhone/Apple Watch), Google Fit (Android), and Fitbit. Please navigate to the appropriate sections below that correspond to your platform to begin.

# %% [markdown]
# ## Apple Devices
#
# Follow the steps below to export data from your iPhone (This will export data from Apple Watch as well)
#
# iPhone/Apple Watch:
# -  Go to the `Health` app on your iPhone.
# -  Click on the profile icon on the top right corner.
# -  Select `Export All Health Data` on the bottom. This process might take some time.
# -  Transfer it to your PC/laptop by email, AirDrop, or any other method you prefer.
# -  Open and Review your data by unzipping the downloaded file. This will include:
#     -   Folders:
#         -   Electrocardiograms
#         -   workout-routines -> workout location data
#     -   Files:
#         -   Export_cda.xml
#         -   export.xml -> data stored in various tags: record, StepCount,  WorkoutActivity, WorkoutEvent, WorkoutStatistics, WorkoutRoute, ActivitySummary, ClinicalRecord, Audiogram, and much more.
#
# ## Android Devices
#
# Android: We recommend using Google Fit as a step counter/sleep tracker.
#
# -   Go to Google Takeout
# -   Under `Select data to include`, first deselect all
# -   Select `Fit`
# -   Select `Next step`
# -   Select `Create Export`
# -   You will receive an email with your information. Download the folder and unzip it.
# -   You are now ready for preprocessing!
#
# ## Fitbit Devices
#
# Fitbit : Step-by-Step Guide to Extract Data from Fitbit
#
# -   Visit the `Fitbit Website`: Open your web browser and go to Fitbit's official website (Fitbit).
#     -   Access Your Account: Click on the login link and enter your credentials to access your account.
#
# -   Access the Dashboard
#
#     -   Navigate to Settings: Once logged in, locate and click on the Data Export panel on the left side of the page.
#
# -   `Google Takeout`
#
#     -   This will take you to Google Takeout.
#     -   Choose Data Types: Select the types of data you want to include, in this case select Fitbit
#
# -   `Export Your Data`
#
#     -   Choose export destination and frequency, for this project select Export once.
#     -   Create Export: Choose this option, you’ll get an email with the download link.
#
# -   Download the data and review the contents.

# %% [markdown]
# ## Processing Your Data
#
# We have provided scripts that will process the data. These scripts essentially store the data in a standardized data format. For example, All the data is stored in a per day basis, cumilating all the steps,sleep..etc in a 24 hour data range.
#
# Navigate to the section that corresponds to your platform
#
# ## Apple
# -   Run the following scripts in this particular order
# -   Run `convert_xml_csv.py`
# -   Run `get_sleep.py`
# -   RUn `get_steps.py`
# -   Make sure that the raw data file in the given the appropriate path
#
# ## Android
# -   Run `google_fit_sleep.py`
# -   Run `google_fit_step.py`
# -   Make sure that the raw data file in the given the appropriate path
#
# ## Fitbit
# -   Run `fitbit_preprocess.py`
# -   Make sure that the raw data file in the given the appropriate path

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Based on your health interests, identify a hypothesis. Why are you interested in this hypothesis? Choose your independent and dependent variables.
#
# In this notebook, we're going to have you analyze the relationship between dependent variable and independent variable.
#
# The sample data is on hours of sleep per day and the number of steps taken per day.

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# Make a prediction, how do you think these two variables are related? Positively, negatively, or not at all? Why do you think that?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# ## Loading and Visualizing Your Data

# %% [markdown]
# ### Loading the Data

# %% [markdown]
# To start, we need to load in our data. We have provided sample data for you, but we recommend you upload your own data to this collab environment and modify `var1_name`, `var2_name` and `var1_file`, `var2_file` to reflect your own data.
#
# Your data should match the format of the sample data `sleep.csv` and `step.csv`. They should be csv files two columns: `Date` and `Total Value`.

# %%
import pandas as pd

var1_name = "Sleep"
var2_name = "Step"
var1_file = "sample_data/Sleepanalysis_summary.csv"
var2_file = "sample_data/StepCount_summary.csv"

var1 = pd.read_csv(var1_file)
var2 = pd.read_csv(var2_file)

# %% [markdown]
# If all is well, this cell should have loaded both of your csv files. Let's see what the data looks like!

# %%
print(f"A subset of {var1_name} data:")
var1.head()
# Out:
# A subset of Sleep data:
#          Date  Total Value
# 0  2023-06-25     8.336667
# 1  2023-06-27     7.527500
# 2  2023-06-28     8.670278
# 3  2023-06-29     7.762500
# 4  2023-06-30     8.353056

# %%
print(f"A subset of {var2_name} data:")
var2.head()
# Out:
# A subset of Step data:
#          Date  Total Value
# 0  2023-06-25         2046
# 1  2023-06-26         1550
# 2  2023-06-27         3622
# 3  2023-06-28         2976
# 4  2023-06-29         1272

# %% [markdown]
# ### Visualizing the Data

# %%
print(f"A subset of {var1_name} data:")
var1.head()
# Out:
# A subset of Sleep data:
#          Date  Total Value
# 0  2023-06-25     8.336667
# 1  2023-06-27     7.527500
# 2  2023-06-28     8.670278
# 3  2023-06-29     7.762500
# 4  2023-06-30     8.353056

# %% [markdown]
# Visualizing sleep minutes data by dates:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))  # Set the figure size
plt.bar(var1['Date'], var1['Total Value'], label=f'{var1_name}',  width=0.5, color='green') #use bar chart with x data as date and y data as total value
plt.ylabel(f'{var1_name} (minutes)') # set y label
plt.xlabel('Date') # set x label
plt.title(f'{var1_name} data') # set title
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# Visualizing number of steps by dates:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))  # Set the figure size

plt.bar(var2['Date'], var2['Total Value'], label=f'{var2_name}', width=0.5, color='skyblue')
plt.ylabel(f'{var2_name}')
plt.xlabel('Date')
plt.title(f'{var2_name} data')
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# Now, we're going to try to visualize the data together. Since each of our data points has a date and a value, we're going to group together points by date.

# %%
combined_table = pd.merge(var1, var2, on="Date", suffixes=[' ' + var1_name, ' ' + var2_name])
combined_table.head()
# Out:
#          Date  Total Value Sleep  Total Value Step
# 0  2023-06-25           8.336667              2046
# 1  2023-06-27           7.527500              3622
# 2  2023-06-28           8.670278              2976
# 3  2023-06-29           7.762500              1272
# 4  2023-06-30           8.353056              5031

# %%
plt.scatter(combined_table[f"Total Value {var1_name}"], combined_table[f"Total Value {var2_name}"])
plt.xlabel(f"{var1_name} Value")
plt.ylabel(f"{var2_name} Value")
plt.title(f"{var1_name} vs {var2_name} Scatter Plot")
plt.show()

# %% [markdown]
# This cell plots the amount of the first variable with respect to the second variable. Do you see any obvious relationship between the two? Do they seem positively correlated? Negatively correlated? Is this something you expect? We will quantify this later using statistical tests.

# %% [markdown]
# Answer: [YOUR ANSWER HERE]

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### t-test

# %% [markdown]
# Next, we're going to try to do an analysis on our data using a t-test. Recall that a t-test is a statistical test used for evaluating whether the relationship between two groups is significant or not. If you want to know more about the details, you can read about it [here](https://en.wikipedia.org/wiki/Student%27s_t-test).

# %%
from scipy import stats
stats.ttest_ind(combined_table[f"Total Value {var1_name}"], combined_table[f"Total Value {var2_name}"])
# Out:
# TtestResult(statistic=-30.962943356884843, pvalue=2.932288786357644e-123, df=558.0)

# %% [markdown]
# If this worked, you should see something like `TtestResult(statistic=[t value here], pvalue=[p value here], df=[degrees of freedom here])`.

# %% [markdown]
# What does this result mean? Interpret the test result in words. Does this result support or negate your hypothesis?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# Now we're going to fit our data using [linear regression](https://en.wikipedia.org/wiki/Linear_regression). Linear regression fits two variables using a linear model. It tries to minimize the mean-squared error between the generated model and the actual data. By doing this, we try to see how we can predict the second variable given only the first.

# %%
result = stats.linregress(combined_table[f"Total Value {var1_name}"], combined_table[f"Total Value {var2_name}"])
slope, intercept, r, p, se_slope, se_intercept = result.slope, result.intercept, result.rvalue, result.pvalue, result.stderr, result.intercept_stderr
plt.scatter(combined_table[f"Total Value {var1_name}"], combined_table[f"Total Value {var2_name}"], label='Data Points')
plt.plot(combined_table[f"Total Value {var1_name}"], intercept + slope*combined_table[f"Total Value {var1_name}"], 'r', label='fitted line')
plt.xlabel(f"{var1_name} Value")
plt.ylabel(f"{var2_name} Value")
plt.title(f"{var1_name} vs {var2_name} Fitted Plot")
plt.legend()
plt.show()

# %% [markdown]
# You should have a red line fitting your data drawn out. In your opinion, does the model seem to fit the data well?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# Below, we show the actual model we fitted. What does this model claim is the relationship between the two variables? Write it out in words.

# %%
print(f"Slope, intercept: {slope}, {intercept}")
# Out:
# Slope, intercept: -29.575047541187065, 7375.027021176524

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# Now, let's do some qualitative analysis of our model using meta-statistics. First, the correlation coefficient:

# %%
print(f"Correlation coefficient (R^2): {r}")
# Out:
# Correlation coefficient (R^2): -0.023731862492770584

# %% [markdown]
# What does this statistic mean when applied to our data? Does it support or negate your hypothesis?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %%
print(f"p-value: {p}")
print(f"Slope standard error: {se_slope}")
print(f"Intercept standard error: {se_intercept}")
# Out:
# p-value: 0.6925556456444224
# Slope standard error: 74.7220706223072
# Intercept standard error: 635.2650981014527

# %% [markdown]
# Given the p-value and standard errors, do you think our model is good or bad? Why or why not?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# If you think the model is good, why do you think this model is sufficient to explain our data? How does this explain an aspect of your life/health? If you don't think the model is good, why do you think we aren't able to explain the data this way? Propose an alternative method of modeling the relationship between these two points, if there is one. If you can't think of an alternative justify why we shouldn't be able to fit the data.

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# ### Polynomial Regression Model

# %% [markdown]
# In this section, we are going to use a more powerful model than linear regression, namely using polynomials. Here, we have a tuneable hyperparameter $n$, which signifies the order of the polynomial. For instance, if $n = 2$, we are finding the best $a, b, c$ such that our model $$f(x) = a x^2 + b x + c$$ predicts $y$ as closely as possible based on our data.

# %% [markdown]
# This is actually the same as linear regression if we set $n$ correctly. What is $n$ in linear regression?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# First, set $n$.

# %%
n = 2

# %% [markdown]
# Now, we run the regression itself.

# %%
from scipy import odr
import numpy as np

x, y = combined_table[f"Total Value {var1_name}"], combined_table[f"Total Value {var2_name}"]
poly_model = odr.polynomial(n)
data = odr.Data(x, y)
odr_obj = odr.ODR(data, poly_model)
output = odr_obj.run()
poly = np.poly1d(output.beta[::-1])
x_sorted = sorted(x)
poly_y = poly(x_sorted)
plt.scatter(x, y, label="data")
plt.plot(x_sorted, poly_y, label="polynomial fit", color='r')
plt.legend()
plt.show()

# %% [markdown]
# You should have a red line fitting your data drawn out. In your opinion, does the model seem to fit the data well? How does it compare in quality to the linear regression?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# Here is the model we predicted:

# %%
print("Predicted coefficients in decreasing order:", output.beta)
print("Coefficient standard errors:", output.sd_beta)
# Out:
# Predicted coefficients in decreasing order: [ 8.64230082 14.869517   71.01465893]
# Coefficient standard errors: [1015.32031085  323.94954768   22.79268527]

# %% [markdown]
# Given the standard errors, do you think our model is good or bad? Why or why not?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# Given both this analysis and the linear regression analysis, which do you think is a superior model? What is a benefit of the linear regression model over this one? What is a benefit of the polynomial model over the linear one?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# Now try varying $n$ and running the above cells again. Does any particular value of $n$ stand out as being a better fit than the others? If so, which $n$?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# ## Reflection

# %% [markdown]
# Reflect on the self-experimentation experience and write a paragraph describing it.
#
# 1. What did you learn from the process? In terms of data analysis procedure? In terms of your personal health?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# 2. Given all of the statistical tests you ran, would you argue that your hypothesis was confirmed, rejected, or neither? Why? Justify it using the statistics from the tests.

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# 3. Suppose your hypothesis were confirmed. How would you explain the reasoning behind it? Now suppose your hypothesis were conclusively negated. How would this change your preconceived notions?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# 4. What are the limitations of your experiment/data-collection/analysis?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# 5. What would you change in the experiemental setup if you were to test the hypothesis again? e.g. doing it over a longer time frame, etc. Please justify why this change would be helpful for testing your hypothesis. Try to address the limitations you pointed out in part 3.

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# 6. What steps can you take to improve your health based on this experiment?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# 7. Given that you have done this analysis on a set of two variables, what other variables do you think would be interesting to examine in a simliar fashion? What do you think you would find?

# %% [markdown]
# ANSWER: [YOUR ANSWER HERE]

# %% [markdown]
# ## Survey

# %% [markdown]
# 1. Did you face any issues from running the notebook? Was the information on the course sufficient to complete the project, or did you need to seek additional resources?
# 2. Did you think this exercise was effective in teaching you how to analyze your own health data and draw conclusions from it?
# 3. Do you wish this to be any different? What do you change from this
# 4. How do you perceive the balance between theoretical knowledge and practical skills in this assignment?
# 5. How user-friendly did you find the tools, platforms, and instructions used for data export and analysis?

# %% [markdown]
# 1. [YOUR ANSWER HERE]
# 2. [YOUR ANSWER HERE]
# 3. [YOUR ANSWER HERE]
# 4. [YOUR ANSWER HERE]
# 5. [YOUR ANSWER HERE]
